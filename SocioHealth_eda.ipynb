# %%
# Dependecy import
import pandas as pd
import matplotlib.pyplot as plt

# File to Load (Remember to change the path if needed.)
data_to_load = "Resources/us_county_sociohealth_data.csv"

sociohealth_df = pd.read_csv(data_to_load)

sociohealth_df.head()
# Out:
#    SN  fips    state   county        lat        lon  total_population  \
# 0   1  1001  Alabama  Autauga  32.534928 -86.642748             55049
# 1   2  1003  Alabama  Baldwin  30.727489 -87.722575            199510
# 2   3  1005  Alabama  Barbour  31.869589 -85.393213             26614
# 3   4  1007  Alabama     Bibb  32.998634 -87.126480             22572
# 4   5  1009  Alabama   Blount  33.980878 -86.567383             57704
#
#      area_sqmi  population_density_per_sqmi  num_deaths  ...  \
# 0   594.446120                    92.605533       791.0  ...
# 1  1589.807425                   125.493187      2967.0  ...
# 2   884.875776                    30.076538       472.0  ...
# 3   622.582355                    36.255444       471.0  ...
# 4   644.806508                    89.490412      1085.0  ...
#
#   percentile_rank_minorities  percentile_rank_limited_english_abilities  \
# 0                     0.6339                                     0.5355
# ...

# %%
# Basic EDA to see what we have
print(sociohealth_df.shape)
sociohealth_df.columns
# Out:
# (3144, 184)
# Index(['SN', 'fips', 'state', 'county', 'lat', 'lon', 'total_population',
#        'area_sqmi', 'population_density_per_sqmi', 'num_deaths',
#        ...
#        'percentile_rank_minorities',
#        'percentile_rank_limited_english_abilities',
#        'percentile_rank_minority_status_and_language_theme',
#        'percentile_rank_multi_unit_housing', 'percentile_rank_mobile_homes',
#        'percentile_rank_overcrowding', 'percentile_rank_no_vehicle',
#        'percentile_rank_institutionalized_in_group_quarters',
#        'percentile_rank_housing_and_transportation',
#        'percentile_rank_social_vulnerability'],
#       dtype='object', length=184)

# %%
sociohealth_df.dtypes
# Out:
# SN                                                       int64
# fips                                                    object
# state                                                   object
# county                                                  object
# lat                                                    float64
#                                                         ...
# percentile_rank_overcrowding                           float64
# percentile_rank_no_vehicle                             float64
# percentile_rank_institutionalized_in_group_quarters    float64
# percentile_rank_housing_and_transportation             float64
# percentile_rank_social_vulnerability                   float64
# Length: 184, dtype: object

# %%
sociohealth_df.describe()
# Out:
#                 SN          lat          lon  total_population      area_sqmi  \
# count  3144.000000  3144.000000  3144.000000      3.144000e+03    3144.000000
# mean   1572.500000    38.457313   -92.280536      1.043681e+05    1124.200881
# std     907.738949     5.307184    12.921097      3.581135e+05    3611.454730
# min       1.000000    19.598724  -166.890423      7.600000e+01       2.050706
# 25%     786.750000    34.703544   -98.223328      1.099750e+04     430.728099
# 50%    1572.500000    38.388419   -90.400294      2.575050e+04     616.005281
# 75%    2358.250000    41.806737   -83.435911      6.774300e+04     924.041689
# max    3144.000000    69.311848   -67.629217      1.005716e+07  145492.910700
#
#        population_density_per_sqmi    num_deaths  \
# count                  3144.000000   2851.000000
# mean                    276.839299   1363.905998
# std                    1864.419086   3605.025873
# min                       0.038490     32.000000
# ...

# %%
state_array = sociohealth_df['state'].unique()
state_array
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# Average county population for each state

Avg_pop_per_state = sociohealth_df.groupby(["state"]).mean()['total_population']
Avg_pop_per_state
# Out:
# state
# Alabama                  72256.179104
# Alaska                   25408.793103
# Arizona                 448571.800000
# Arkansas                 39579.626667
# California              666451.827586
# Colorado                 83738.984375
# Connecticut             448571.250000
# Delaware                311565.000000
# District of Columbia    659009.000000
# Florida                 297529.119403
# Georgia                  63517.735849
# Hawaii                  282734.600000
# Idaho                    37170.068182
# Illinois                125996.901961
# Indiana                  71625.847826
# Iowa                     31379.686869
# Kansas                   27602.780952
# Kentucky                 36766.575000
# Louisiana                72588.593750
# Maine                    83120.187500
# Maryland                248329.250000
# Massachusetts           481581.642857
# Michigan                119392.771084
# Minnesota                62653.655172
# ...

# %%
# Getting the average_number_of_physically_unhealthy_days averaging the column averages grouped by state

Avg_number_of_unhealthy_days = sociohealth_df.groupby(["state"]).mean()['average_number_of_physically_unhealthy_days']
Avg_number_of_unhealthy_days
# Out:
# state
# Alabama                 4.960199
# Alaska                  3.948983
# Arizona                 4.330210
# Arkansas                4.762518
# California              3.744186
# Colorado                3.480310
# Connecticut             3.011815
# Delaware                3.862909
# District of Columbia    2.885692
# Florida                 4.373422
# Georgia                 3.846145
# Hawaii                  3.278869
# Idaho                   3.846763
# Illinois                3.724628
# Indiana                 4.085851
# Iowa                    3.175117
# Kansas                  3.508250
# Kentucky                5.032550
# Louisiana               4.823616
# Maine                   3.692927
# Maryland                3.349640
# Massachusetts           3.481575
# Michigan                4.074548
# Minnesota               3.034481
# Mississippi             4.779324
# Missouri                4.622634
# Montana                 3.730420
# Nebraska                3.136440
# ...

# %%
Avg_number_of_uninsured = sociohealth_df.groupby(["state"]).mean()['num_uninsured']
Avg_number_of_uninsured
# Out:
# state
# Alabama                  6538.044776
# Alaska                   3266.448276
# Arizona                 45731.600000
# Arkansas                 3015.720000
# California              47242.724138
# Colorado                 6410.156250
# Connecticut             22765.250000
# Delaware                15528.666667
# District of Columbia    24833.000000
# Florida                 39044.223881
# Georgia                  8565.899371
# Hawaii                  13256.250000
# Idaho                    3827.272727
# Illinois                 8214.607843
# Indiana                  5724.641304
# Iowa                     1408.323232
# Kansas                   2317.200000
# Kentucky                 1926.275000
# Louisiana                5825.031250
# Maine                    6678.937500
# Maryland                14746.750000
# Massachusetts           13027.785714
# Michigan                 5983.783133
# Minnesota                2707.390805
# Mississippi              4296.414634
# ...

# %%
state_metric_df = pd.DataFrame({
    "Average Population for Each County by State" : Avg_pop_per_state,
    "Average Uninsured Per State" : Avg_number_of_uninsured,
    "Average Number of Unhealthy Days" : Avg_number_of_unhealthy_days
    })

state_metric_df
# Out:
#                       Average Population for Each County by State  \
# state
# Alabama                                              72256.179104
# Alaska                                               25408.793103
# Arizona                                             448571.800000
# Arkansas                                             39579.626667
# California                                          666451.827586
# Colorado                                             83738.984375
# Connecticut                                         448571.250000
# Delaware                                            311565.000000
# District of Columbia                                659009.000000
# Florida                                             297529.119403
# Georgia                                              63517.735849
# Hawaii                                              282734.600000
# Idaho                                                37170.068182
# ...

# %%
state_metric_df["Average Uninsured Per State"] = state_metric_df["Average Uninsured Per State"].map("{:.2f}".format)
state_metric_df["Average Number of Unhealthy Days"] = state_metric_df["Average Number of Unhealthy Days"].map("{:.2f}".format)
state_metric_df["Average Population for Each County by State"] = state_metric_df["Average Population for Each County by State"].map("{:.2f}".format)
state_metric_df
# Out:
#                      Average Population for Each County by State  \
# state
# Alabama                                                 72256.18
# Alaska                                                  25408.79
# Arizona                                                448571.80
# Arkansas                                                39579.63
# California                                             666451.83
# Colorado                                                83738.98
# Connecticut                                            448571.25
# Delaware                                               311565.00
# District of Columbia                                   659009.00
# Florida                                                297529.12
# Georgia                                                 63517.74
# Hawaii                                                 282734.60
# Idaho                                                   37170.07
# ...

# %%
sociohealth_df.select([''])
