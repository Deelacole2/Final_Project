# %%
# import dependencies
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Import our input dataset
hospitals_df = pd.read_csv('Resources/us_hospital_locations.csv')
hospitals_df.head()
# Out:
#               X             Y  FID        ID  \
# 0 -1.331889e+07  4.346975e+06    1   5793230
# 1 -1.322651e+07  4.049626e+06    2  53391362
# 2 -1.315620e+07  4.031978e+06    3  11190023
# 3 -1.317190e+07  4.041752e+06    4  17090028
# 4 -1.313208e+07  4.037270e+06    5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# 3     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  NOT AVAILABLE
# 4  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706  NOT AVAILABLE
#
#    ...             VAL_DATE                           WEBSITE       STATE_ID  \
# 0  ...  2014/02/10 00:00:00      http://www.hanfordhealth.com  NOT AVAILABLE
# 1  ...  2014/02/10 00:00:00  http://www.losrobleshospital.com  NOT AVAILABLE
# 2  ...  2014/02/10 00:00:00             http://www.elalax.com  NOT AVAILABLE
# 3  ...  2014/02/10 00:00:00         http://sch-hollywood.com/  NOT AVAILABLE
# 4  ...  2014/02/10 00:00:00      http://www.khbaldwinpark.com  NOT AVAILABLE
#
#                                     ALT_NAME ST_FIPS        OWNER TTL_STAFF  \
# 0                              NOT AVAILABLE       6  PROPRIETARY      -999
# 1                              NOT AVAILABLE       6  PROPRIETARY      -999
# 2                              NOT AVAILABLE       6  PROPRIETARY      -999
# 3  HOLLYWOOD COMMUNITY HOSPITAL OF HOLLYWOOD       6  PROPRIETARY      -999
# 4                              NOT AVAILABLE       6  PROPRIETARY      -999
#
#    BEDS         TRAUMA  HELIPAD
# 0    49  NOT AVAILABLE        N
# 1    62  NOT AVAILABLE        N
# 2   127  NOT AVAILABLE        N
# 3   100  NOT AVAILABLE        N
# 4    95  NOT AVAILABLE        N
#
# [5 rows x 34 columns]

# %%
# Extract Acute Care Hospitals form DataFrame
acute_care_df = hospitals_df[hospitals_df['TYPE']=='GENERAL ACUTE CARE']
acute_care_df.head()
# Out:
#               X             Y  FID        ID  \
# 0 -1.331889e+07  4.346975e+06    1   5793230
# 1 -1.322651e+07  4.049626e+06    2  53391362
# 2 -1.315620e+07  4.031978e+06    3  11190023
# 3 -1.317190e+07  4.041752e+06    4  17090028
# 4 -1.313208e+07  4.037270e+06    5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# 3     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  NOT AVAILABLE
# 4  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706  NOT AVAILABLE
#
#    ...             VAL_DATE                           WEBSITE       STATE_ID  \
# 0  ...  2014/02/10 00:00:00      http://www.hanfordhealth.com  NOT AVAILABLE
# 1  ...  2014/02/10 00:00:00  http://www.losrobleshospital.com  NOT AVAILABLE
# 2  ...  2014/02/10 00:00:00             http://www.elalax.com  NOT AVAILABLE
# 3  ...  2014/02/10 00:00:00         http://sch-hollywood.com/  NOT AVAILABLE
# 4  ...  2014/02/10 00:00:00      http://www.khbaldwinpark.com  NOT AVAILABLE
#
#                                     ALT_NAME ST_FIPS        OWNER TTL_STAFF  \
# 0                              NOT AVAILABLE       6  PROPRIETARY      -999
# 1                              NOT AVAILABLE       6  PROPRIETARY      -999
# 2                              NOT AVAILABLE       6  PROPRIETARY      -999
# 3  HOLLYWOOD COMMUNITY HOSPITAL OF HOLLYWOOD       6  PROPRIETARY      -999
# 4                              NOT AVAILABLE       6  PROPRIETARY      -999
#
#    BEDS         TRAUMA  HELIPAD
# 0    49  NOT AVAILABLE        N
# 1    62  NOT AVAILABLE        N
# 2   127  NOT AVAILABLE        N
# 3   100  NOT AVAILABLE        N
# 4    95  NOT AVAILABLE        N
#
# [5 rows x 34 columns]

# %%
# Find how many acute care locations
len(acute_care_df.index)
# Out:
# 4481

# %%
# Keep only OPEN acute care hospitals
acute_care_df = acute_care_df[acute_care_df['STATUS']=='OPEN']
len(acute_care_df.index)
# Out:
# 4268

# %%
 # Keep only relevant columns
cond_acute_care_df = acute_care_df[['NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'LATITUDE', 'LONGITUDE']]
cond_acute_care_df.head()
# Out:
#                                                 NAME  \
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
# 5                   LAKEWOOD REGIONAL MEDICAL CENTER
#
#                      ADDRESS             CITY STATE    ZIP   LATITUDE  \
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  34.154939
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  34.023647
# 3     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  34.096391
# 4  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706  34.063039
# 5     3700 EAST SOUTH STREET         LAKEWOOD    CA  90712  33.859707
#
#     LONGITUDE
# 1 -118.815736
# 2 -118.184165
# 3 -118.325235
# 4 -117.967438
# 5 -118.148403

# %%
# make new column from turple of 'LATITUDE' and 'LONGITUDE'
cond_acute_care_df['GEOLOCATION'] = list(zip(cond_acute_care_df['LATITUDE'], cond_acute_care_df['LONGITUDE']))
cond_acute_care_df.head()
# Out:
# <ipython-input-6-81cd1ca4e053>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cond_acute_care_df['GEOLOCATION'] = list(zip(cond_acute_care_df['LATITUDE'], cond_acute_care_df['LONGITUDE']))
#                                                 NAME  \
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
# 5                   LAKEWOOD REGIONAL MEDICAL CENTER
#
#                      ADDRESS             CITY STATE    ZIP   LATITUDE  \
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  34.154939
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  34.023647
# 3     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  34.096391
# 4  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706  34.063039
# 5     3700 EAST SOUTH STREET         LAKEWOOD    CA  90712  33.859707
#
#     LONGITUDE                         GEOLOCATION
# 1 -118.815736  (34.1549388720001, -118.815736391)
# 2 -118.184165      (34.023647302, -118.184164805)
# 3 -118.325235  (34.0963913570001, -118.325234871)
# 4 -117.967438      (34.063038932, -117.967437788)
# 5 -118.148403  (33.8597066200001, -118.148402965)

# %%
# generate random locations in USA
def random_lat_lon(n, lat_min, lat_max, lon_min, lon_max):
    """
    this code produces an array with pairs lat, lon
    """
    lat = np.random.uniform(lat_min, lat_max, n)
    lon = np.random.uniform(lon_min, lon_max, n)
    
    return list(zip(lat, lon))

#    return np.array(tuple(zip(lat, lon))).tolist()
rand_loc = random_lat_lon(1000, 26.5, 47.0, -70.0, -130.0)
print(rand_loc)
# Out:
# [(27.783614388618506, -81.24981944601676), (37.114955989647065, -125.66822873732477), (32.559801338883574, -83.48043864291694), (31.796704750477282, -124.0792911494604), (39.87327099773287, -83.3659601007121), (39.12467837793843, -93.32652380198472), (29.59790064435151, -79.56584735652802), (31.397788896408343, -83.51957737952358), (40.096748323429864, -103.38980483401629), (28.232831314964148, -110.09466890455386), (43.521834521336906, -98.37406674498162), (35.3313370191259, -82.6664478788968), (39.36821815396229, -84.85781304289095), (42.312379853414484, -112.41331716180026), (44.447441112513985, -85.94254653588511), (34.02610867663159, -125.52817401635565), (43.921953418714835, -119.72112611554064), (33.13363403255432, -74.20168437181484), (43.232417759224745, -108.22927809442507), (37.39168372861033, -85.9003235674934), (30.04744371216457, -72.08509326848
        dist = vincenty(i, row, miles=True)
        dist_list.append(dist)
    min_dist.append(min(dist_list))
    if min(dist_list)>60:
        med_desert.append('Yes')
    else:
        med_desert.append('No')

# %%
# make series into dataframe columns

medical_desert_df = pd.DataFrame()
medical_desert_df['Random_Location'] = rand_loc
medical_desert_df['Min_Distance_From_Acute_Hospital'] = min_dist
medical_desert_df['Is_Medical_Desert'] = med_desert
medical_desert_df[['latitude','longitude']] = pd.DataFrame(medical_desert_df['Random_Location'].tolist(),index=medical_desert_df.index)
medical_desert_df.head()
# Out:
#                              Random_Location  \
# 0   (27.783614388618506, -81.24981944601676)
# 1  (37.114955989647065, -125.66822873732477)
# 2   (32.559801338883574, -83.48043864291694)
# 3   (31.796704750477282, -124.0792911494604)
# 4     (39.87327099773287, -83.3659601007121)
#
#    Min_Distance_From_Acute_Hospital Is_Medical_Desert   latitude   longitude
# 0                         20.807054                No  27.783614  -81.249819
# 1                        176.380978               Yes  37.114956 -125.668229
# 2                          9.640488                No  32.559801  -83.480439
# 3                        287.625790               Yes  31.796705 -124.079291
# 4                          4.877990                No  39.873271  -83.365960

# %%
# Encode categorical data
medical_desert_encoded = pd.get_dummies(medical_desert_df, columns=['Is_Medical_Desert'])
medical_desert_encoded.head()
# Out:
#                              Random_Location  \
# 0   (27.783614388618506, -81.24981944601676)
# 1  (37.114955989647065, -125.66822873732477)
# 2   (32.559801338883574, -83.48043864291694)
# 3   (31.796704750477282, -124.0792911494604)
# 4     (39.87327099773287, -83.3659601007121)
#
#    Min_Distance_From_Acute_Hospital   latitude   longitude  \
# 0                         20.807054  27.783614  -81.249819
# 1                        176.380978  37.114956 -125.668229
# 2                          9.640488  32.559801  -83.480439
# 3                        287.625790  31.796705 -124.079291
# 4                          4.877990  39.873271  -83.365960
#
#    Is_Medical_Desert_No  Is_Medical_Desert_Yes
# 0                     1                      0
# 1                     0                      1
# 2                     1                      0
# 3                     0                      1
# 4                     1                      0

# %%
# backup dataframe
medical_desert_encoded_bkup = medical_desert_encoded

# %%
# import dependencies for machine learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Split data into feature and target
y = medical_desert_encoded['Is_Medical_Desert_Yes']
X = medical_desert_encoded.drop(['Is_Medical_Desert_No', 'Is_Medical_Desert_Yes', 'Random_Location', 'Min_Distance_From_Acute_Hospital'], axis=1)

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Create a LogisticRegression model
classifier = LogisticRegression(solver='saga',
   max_iter=500,
   random_state=1)

# %%
# Train the model with the training data
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500, random_state=1, solver='saga')

# %%
# test the model with the test data
y_pred = classifier.predict(X_test)

# %%
# Calculate accuracy score
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.736

# %%
# Get confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
matrix = confusion_matrix(y_test, y_pred)
print(matrix)
# Out:
# [[143  15]
#  [ 51  41]]

# %%
# print classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.81       158
#            1       0.73      0.45      0.55        92
#
#     accuracy                           0.74       250
#    macro avg       0.73      0.68      0.68       250
# weighted avg       0.74      0.74      0.72       250
