# %%
import json
import pandas as pd
import numpy as np
import re
from sqlalchemy import create_engine
from config import password
import psycopg2
from psycopg2.extras import RealDictCursor

# %%
#establishing the connection
conn = psycopg2.connect(
   database="capstone_db", user='postgres', password='',
   host='capstone.cjj05msruqqh.us-east-2.rds.amazonaws.com', port= '5432', 
   cursor_factory=RealDictCursor
)

#Setting auto commit false
conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

# %%
#Retrieving data
cursor.execute('''SELECT * from us_county_sociohealth_data''')

# %%
#Fetching all rows from the table
result = cursor.fetchall();

# %%
type(result)
# Out:
# list

# %%
result[:1]

# %%
print(pd.DataFrame(np.array(result)))
# Out:
#                                                       0
# 0     {'SN': 1, 'fips': '1001', 'state': 'Alabama', ...
# 1     {'SN': 2, 'fips': '1003', 'state': 'Alabama', ...
# 2     {'SN': 3, 'fips': '1005', 'state': 'Alabama', ...
# 3     {'SN': 4, 'fips': '1007', 'state': 'Alabama', ...
# 4     {'SN': 5, 'fips': '1009', 'state': 'Alabama', ...
# ...                                                 ...
# 3139  {'SN': 3140, 'fips': '56041', 'state': 'Wyomin...
# 3140  {'SN': 3141, 'fips': '56043', 'state': 'Wyomin...
# 3141  {'SN': 3142, 'fips': '56045', 'state': 'Wyomin...
# 3142  {'SN': 3143, 'fips': 'KSC', 'state': 'Missouri...
# 3143  {'SN': 3144, 'fips': 'NYC', 'state': 'New York...
#
# [3144 rows x 1 columns]

# %%
sociohealth_df = pd.DataFrame([i.copy() for i in result])
sociohealth_df
# Out:
#         SN   fips     state         county        lat         lon  \
# 0        1   1001   Alabama        Autauga  32.534928  -86.642748
# 1        2   1003   Alabama        Baldwin  30.727489  -87.722575
# 2        3   1005   Alabama        Barbour  31.869589  -85.393213
# 3        4   1007   Alabama           Bibb  32.998634  -87.126480
# 4        5   1009   Alabama         Blount  33.980878  -86.567383
# ...    ...    ...       ...            ...        ...         ...
# 3139  3140  56041   Wyoming          Uinta  41.287648 -110.547639
# 3140  3141  56043   Wyoming       Washakie  43.904970 -107.682819
# 3141  3142  56045   Wyoming         Weston  43.840417 -104.567663
# 3142  3143    KSC  Missouri    Kansas City  39.130000  -94.550000
# 3143  3144    NYC  New York  New York City  40.660000  -73.940000
#
#       total_population    area_sqmi  population_density_per_sqmi num_deaths  \
# 0                55049   594.446120                    92.605533        791
# ...

# %%
#Closing the connection
conn.close()

# %%
sociohealth_df
# Out:
#         SN   fips     state         county        lat         lon  \
# 0        1   1001   Alabama        Autauga  32.534928  -86.642748
# 1        2   1003   Alabama        Baldwin  30.727489  -87.722575
# 2        3   1005   Alabama        Barbour  31.869589  -85.393213
# 3        4   1007   Alabama           Bibb  32.998634  -87.126480
# 4        5   1009   Alabama         Blount  33.980878  -86.567383
# ...    ...    ...       ...            ...        ...         ...
# 3139  3140  56041   Wyoming          Uinta  41.287648 -110.547639
# 3140  3141  56043   Wyoming       Washakie  43.904970 -107.682819
# 3141  3142  56045   Wyoming         Weston  43.840417 -104.567663
# 3142  3143    KSC  Missouri    Kansas City  39.130000  -94.550000
# 3143  3144    NYC  New York  New York City  40.660000  -73.940000
#
#       total_population    area_sqmi  population_density_per_sqmi num_deaths  \
# 0                55049   594.446120                    92.605533        791
# ...
